# 4     2018-03-21  62.60  63.210  62.52  62.59   2537296.0          0.0
# ...          ...    ...     ...    ...    ...         ...          ...
# 1254  2013-04-03  11.03  11.070  10.91  10.96   5644400.0          0.0
# 1255  2013-04-02  11.08  11.170  10.89  11.02   8940000.0          0.0
# 1256  2013-04-01  10.93  11.050  10.83  11.05   5824000.0          0.0
# 1257  2013-03-28  10.75  11.040  10.70  10.90  19386800.0          0.0
# 1258  2013-03-27  10.66  10.670  10.47  10.53   3761200.0          0.0
#
#       Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# ...

# %%
# Check the data types for one of the dataframes (since they all come from the same API)
VZ_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         1259 non-null   object
#  1   Open         1259 non-null   float64
#  2   High         1259 non-null   float64
#  3   Low          1259 non-null   float64
#  4   Close        1259 non-null   float64
#  5   Volume       1259 non-null   float64
#  6   Ex-Dividend  1259 non-null   float64
#  7   Split Ratio  1259 non-null   float64
#  8   Adj. Open    1259 non-null   float64
#  9   Adj. High    1259 non-null   float64
#  10  Adj. Low     1259 non-null   float64
#  11  Adj. Close   1259 non-null   float64
#  12  Adj. Volume  1259 non-null   float64
# dtypes: float64(12), object(1)
# memory usage: 128.0+ KB

# %%
# Change the 'Date' data in each dataframe to datetime/timestamp, instead of object
VZ_df["Date"] = pd.to_datetime(VZ_df["Date"], format="%Y/%m/%d")
ATT_df["Date"] = pd.to_datetime(ATT_df["Date"], format="%Y/%m/%d")
TMUS_df["Date"] = pd.to_datetime(TMUS_df["Date"], format="%Y/%m/%d")

# Double check that the data type change went through:
VZ_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         1259 non-null   datetime64[ns]
#  1   Open         1259 non-null   float64
#  2   High         1259 non-null   float64
#  3   Low          1259 non-null   float64
#  4   Close        1259 non-null   float64
#  5   Volume       1259 non-null   float64
#  6   Ex-Dividend  1259 non-null   float64
#  7   Split Ratio  1259 non-null   float64
#  8   Adj. Open    1259 non-null   float64
#  9   Adj. High    1259 non-null   float64
#  10  Adj. Low     1259 non-null   float64
#  11  Adj. Close   1259 non-null   float64
#  12  Adj. Volume  1259 non-null   float64
# dtypes: datetime64[ns](1), float64(12)
# memory usage: 128.0 KB

# %%
# Export the dataframes as CSV files for future reference
VZ_df.to_csv("Resources/VZ.csv")
ATT_df.to_csv("Resources/ATT.csv")
TMUS_df.to_csv("Resources/TMUS.csv")

# %% [markdown]
# ## Descriptive Statistics

# %%
VZ_df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1.259000e+03
# mean     49.054948    49.378763    48.694074    49.053047  1.615053e+07
# std       2.557755     2.558734     2.560203     2.560857  1.923956e+07
# min      42.550000    42.900000    38.060000    42.840000  4.108274e+06
# 25%      47.226500    47.512500    46.844300    47.225000  1.095680e+07
# 50%      49.040000    49.365000    48.730000    49.050000  1.358152e+07
# 75%      50.530000    50.870000    50.175000    50.525000  1.778573e+07
# max      56.320000    56.950000    56.320000    56.530000  6.166205e+08
#
#        Ex-Dividend  Split Ratio    Adj. Open    Adj. High     Adj. Low  \
# count  1259.000000       1259.0  1259.000000  1259.000000  1259.000000
# mean      0.007857          1.0    45.285619    45.584667    44.952845
# std       0.065305          0.0     3.894278     3.913690     3.881256
# ...

# %%
ATT_df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1.259000e+03
# mean     36.415957    36.645940    36.169209    36.413693  2.520512e+07
# std       2.780522     2.788135     2.777997     2.793121  1.161271e+07
# min      31.800000    31.980000    30.970000    31.800000  6.862360e+06
# 25%      34.280000    34.505000    34.060000    34.300000  1.795976e+07
# 50%      35.670000    35.860000    35.420000    35.610000  2.230328e+07
# 75%      38.400000    38.610000    38.155000    38.375000  2.913386e+07
# max      43.500000    43.890000    43.330000    43.470000  1.005742e+08
#
#        Ex-Dividend  Split Ratio    Adj. Open    Adj. High     Adj. Low  \
# count  1259.000000       1259.0  1259.000000  1259.000000  1259.000000
# mean      0.007109          1.0    32.786758    32.994911    32.564303
# std       0.057477          0.0     4.336215     4.365929     4.312984
# ...

# %%
TMUS_df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1.259000e+03
# mean     41.181585    41.648775    40.703755    41.192875  4.624104e+06
# std      14.499349    14.591161    14.393460    14.485714  4.397492e+06
# min      10.660000    10.670000    10.470000    10.530000  8.011670e+05
# 25%      30.420000    30.730000    30.005000    30.415000  2.639698e+06
# 50%      38.520000    38.990000    37.910000    38.560000  3.707500e+06
# 75%      56.775000    57.340000    56.260500    56.755000  5.315636e+06
# max      68.560000    68.880000    67.770000    68.320000  8.112980e+07
#
#        Ex-Dividend  Split Ratio    Adj. Open    Adj. High     Adj. Low  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean      0.006434     0.999603    41.255069    41.723374    40.776275
# std       0.228282     0.014091    14.356591    14.445767    14.253086
# ...

# %% [markdown]
# ## Closing Price Trends and Comparison

# %% [markdown]
# ### Closing Prices: Verizon

# %% [markdown]
# 5-Year Period

# %%
# Graph the past 5 years' closing prices
y_5yr = VZ_df["Close"]
x_5yr = VZ_df["Date"]

# initial_close needs to be recalculated
initial_close = y_5yr.iloc[-1]

plt.figure(figsize=(24, 8))
plt.title("Verizon (VZ) Closing Prices, 2013-03-27 to 2018-03-27", fontsize=20)
plt.plot(x_5yr, y_5yr, color='red')

print(VZ_df.describe()["Close"])
print(f"Initial Closing Price: {initial_close}, ({x_5yr.iloc[-1]})")
print(f"Latest Closing Price: {recent_close}, ({x.iloc[0]})")
print(f"Total Change in Price: {round(recent_close - initial_close, 2)}")
# Out:
# count    1259.000000
# mean       49.053047
# std         2.560857
# min        42.840000
# 25%        47.225000
# 50%        49.050000
# 75%        50.525000
# max        56.530000
# Name: Close, dtype: float64
# Initial Closing Price: 48.94, (2013-03-27 00:00:00)
# Latest Closing Price: 47.31, (2018-03-27 00:00:00)
# Total Change in Price: -1.63

# %%
# Graph just the past year's worth of data
mask = (VZ_df["Date"] > '2017-03-26') & (VZ_df["Date"] <= '2018-03-27')
VZ_1yr_df = VZ_df.loc[mask]

y_1yr = VZ_1yr_df["Close"]
x_1yr = VZ_1yr_df["Date"]

# initial_close needs to be recalculated
initial_close = y_1yr.iloc[-1]

plt.figure(figsize=(24, 8))
plt.title("Verizon (VZ) Closing Prices, 2017-03-27 to 2018-03-27", fontsize=20)
plt.plot(x, y, color='red')

print(VZ_1yr_df.describe()["Close"])
print(f"Initial Closing Price: {initial_close}, ({x_1yr.iloc[-1]})")
print(f"Latest Closing Price: {recent_close}, ({x.iloc[0]})")
print(f"Total Change in Price: {round(recent_close - initial_close, 2)}")
# Out:
# count    252.000000
# mean      48.280417
# std        2.635613
# min       42.890000
# 25%       46.435000
# 50%       48.310000
# 75%       49.482500
# max       54.720000
# Name: Close, dtype: float64
# Initial Closing Price: 49.14, (2017-03-27 00:00:00)
# Latest Closing Price: 47.31, (2018-03-27 00:00:00)
# Total Change in Price: -1.83

# %%
# Graph the past month's data (from this dataset)
mask = (VZ_df["Date"] > '2018-02-26') & (VZ_df["Date"] <= '2018-03-27')
VZ_1wk_df = VZ_df.loc[mask]

y_1wk = VZ_1wk_df["Close"]
x_1wk = VZ_1wk_df["Date"]

# initial_close needs to be recalculated
initial_close = y_1wk.iloc[-1]

plt.figure(figsize=(16, 8))
plt.title("Verizon (VZ) Closing Prices, 2018-02-27 to 2018-03-27", fontsize=20)
plt.plot(x_1wk, y_1wk, color='red')

print(VZ_1wk_df.describe()["Close"])
print(f"Initial Closing Price: {initial_close}, ({x_1wk.iloc[-1]})")
print(f"Latest Closing Price: {recent_close}, ({x.iloc[0]})")
print(f"Total Change in Price: {round(recent_close - initial_close, 2)}")
# Out:
# count    21.000000
# mean     48.097143
# std       0.770553
# min      46.290000
# 25%      47.690000
# 50%      48.290000
# 75%      48.710000
# max      49.010000
# Name: Close, dtype: float64
# Initial Closing Price: 48.04, (2018-02-27 00:00:00)
# Latest Closing Price: 47.31, (2018-03-27 00:00:00)
# Total Change in Price: -0.73

# %% [markdown]
# ### Closing Prices: AT&T

# %%
# Line plot for AT&T's closing prices over time
y = ATT_df["Close"]
x = ATT_df["Date"]

plt.figure(figsize=(24,8))
plt.title("AT&T (T) Closing Prices, 2013-03-27 to 2018-03-27", fontsize=20)
plt.plot(x, y)

print(ATT_df.describe()["Close"])
# Out:
# count    1259.000000
# mean       36.413693
# std         2.793121
# min        31.800000
# 25%        34.300000
# 50%        35.610000
# 75%        38.375000
# max        43.470000
# Name: Close, dtype: float64

# %%
# Charting closing prices for the past year
mask = (ATT_df["Date"] > '2017-03-26') & (VZ_df["Date"] <= '2018-03-27')
ATT_1yr_df = ATT_df.loc[mask]

y = ATT_1yr_df["Close"]
x = ATT_1yr_df["Date"]

plt.figure(figsize=(24,8))
plt.title("AT&T (T) Closing Prices, 2017-07-27 to 2018-03-27", fontsize=20)
plt.plot(x, y)

print(ATT_1yr_df.describe()["Close"])
# Out:
# count    252.000000
# mean      37.520992
# std        1.776123
# min       32.860000
# 25%       36.480000
# 50%       37.715000
# 75%       38.562500
# max       41.760000
# Name: Close, dtype: float64

# %%
# Graph the past month's data (from this dataset)
mask = (ATT_df["Date"] > '2018-02-26') & (VZ_df["Date"] <= '2018-03-27')
ATT_1wk_df = ATT_df.loc[mask]

y_1wk = ATT_1wk_df["Close"]
x_1wk = ATT_1wk_df["Date"]

# initial_close needs to be recalculated
initial_close = y_1wk.iloc[-1]

plt.figure(figsize=(16, 8))
plt.title("AT&T (T) Closing Prices, 2018-02-27 to 2018-03-27", fontsize=20)
plt.plot(x_1wk, y_1wk)

print(ATT_1wk_df.describe()["Close"])
# Out:
# count    21.000000
# mean     36.407619
# std       0.844955
# min      34.690000
# 25%      36.000000
# 50%      36.700000
# 75%      37.030000
# max      37.390000
# Name: Close, dtype: float64

# %% [markdown]
# ### Closing Prices: T-Mobile

# %%
# Graph the past 5 years' closing prices
mask = (TMUS_df["Date"] > '2013-03-26') & (VZ_df["Date"] <= '2018-03-27')
VZ_df = TMUS_df.loc[mask]

y_5yr = TMUS_df["Close"]
x_5yr = TMUS_df["Date"]

# initial_close needs to be recalculated
initial_close = y_5yr.iloc[-1]

plt.figure(figsize=(24, 8))
plt.title("T-Mobile (TMUS) Closing Prices, 2013-03-27 to 2018-03-27", fontsize=20)
plt.plot(x_5yr, y_5yr, color='fuchsia')

print(TMUS_df.describe()["Close"])
# Out:
# count    1259.000000
# mean       41.192875
# std        14.485714
# min        10.530000
# 25%        30.415000
# 50%        38.560000
# 75%        56.755000
# max        68.320000
# Name: Close, dtype: float64

# %%
# Closing prices for the past year
mask = (TMUS_df["Date"] > '2017-03-26') & (VZ_df["Date"] <= '2018-03-27')
TMUS_1yr_df = TMUS_df.loc[mask]

y_1yr = TMUS_1yr_df["Close"]
x_1yr = TMUS_1yr_df["Date"]

plt.figure(figsize=(24,8))
plt.title("T-Mobile (TMUS) Closing Prices, 2017-07-27 to 2018-03-27", fontsize=20)
plt.plot(x_1yr, y_1yr, color="fuchsia")

print(TMUS_1yr_df.describe()["Close"])
# Out:
# count    252.000000
# mean      62.937679
# std        2.407560
# min       55.360000
# 25%       61.387500
# 50%       63.255000
# 75%       64.351250
# max       68.320000
# Name: Close, dtype: float64

# %%
# Graph data from the past month
mask = (TMUS_df["Date"] > '2018-02-26') & (VZ_df["Date"] <= '2018-03-27')
TMUS_1wk_df = TMUS_df.loc[mask]

y_1wk = TMUS_1wk_df["Close"]
x_1wk = TMUS_1wk_df["Date"]

# initial_close needs to be recalculated
initial_close = y_1wk.iloc[-1]

plt.figure(figsize=(16, 8))
plt.title("T-Mobile (TMUS) Closing Prices, 2018-02-27 to 2018-03-27", fontsize=20)
plt.plot(x_1wk, y_1wk, color='fuchsia')

print(TMUS_1wk_df.describe()["Close"])
# Out:
# count    21.000000
# mean     62.922857
# std       1.839367
# min      59.740000
# 25%      61.380000
# 50%      62.950000
# 75%      64.710000
# max      65.250000
# Name: Close, dtype: float64
